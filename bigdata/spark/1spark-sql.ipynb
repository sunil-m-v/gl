# %% [markdown]
# # Basic Dataframe code

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.config("spark.some.config.option", "some-value").getOrCreate()

# %%
json file is in the HDFS(Hue)

# %%
df = spark.read.json('/user/gl_faculty_greatlearning/spark_recording/people.json')

# %%
spark.read.csv('abc.csv')

# %%
df

# %%
DataFrame[age:bigint, name:string]

# %%
df.head()

# %%
Displays the content of the DataFrame to stdout, Very similar to Pandas

# %%
df.show()

# %%
df.PrintSchema()

# %%
df.select("name").show()

# %%
df.select(df['name'], df['age'] +1).show()

# %%
df2 = df.select(df['name'], df['age'] +1)

# %%
df2

# %%
df2.show()

# %%
df.filter(df['age']> 18).show()

# %%
df.groupBy("age").count().show()

# %% [markdown]
# # Register the DataFrame as a SQL temporary view

# %%
df.createOrReplaceTempView("people")

# %%
sqlDF = spark.sql("SELECT * FROM people")

# %%
sqlDF

# %%
sqlDF.show()

# %% [markdown]
# # Spark context: RDD

# %%
sc = spark.sparkContext

# %%
#Load a text file and convert each line to a Row.
lines = sc.textFile('/user/gl_faculty_greatlearning/spark_recording/kmeans_sample.txt')

# %%
lines.top(3)

# %%
lines.take(2)

# %%
parts = lines.map(lambda 1: 1.split(" , "))

# %%
parts.top(2)

# %% [markdown]
# # programmatic_schema_example

# %%
sc = spark.sparkContext

# %%
" andy "

# %%
#load a text file and convert each line to a Row
lines = sc.textFile('/user/gl_faculty_greatlearning/spark_recording/people.txt')
parts = lines.map(lambda 1: 1.split(" , "))
#Each line is converted to a tuple
people = parts.map(lambda p: (p[0], p[1].strip()))

# %%
people.take(2)

# %%
people.top(2)

# %%
people

# %% [markdown]
# # Need to define schema by providing datatypes of all the columns

# %%
schema = StructType([
StructField('name', StringType(), True)
StructField('age', StringType(), True)
])

# %%
#Apply the schema to the RDD
SchemaPeople = spark.createDataFrame(people, schema)

# %%
schemaPeople.show()

# %%
#creates a temporary view using the DataFrame
schemaPeople.createOrReplaceTempView("people")

# %%
#SQL can be run over DataFrames that have been registered as a table
results = spark.sql("SELECT name FROM people")

# %%
results.show()

# %%
spark.stop()
